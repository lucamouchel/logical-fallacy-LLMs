# %%
import pandas as pd
pd.set_option('display.max_colwidth', 500)

# %%
df = pd.read_csv('../data/MultiFc data/test.tsv', delimiter='\t')
df.reset_index(inplace=True)

# %%
df.head()
# Out:
#       level_0  \
# 0  pomt-14759
# 1  pomt-02596
# 2  snes-00569
# 3  pomt-14237
# 4  snes-05947
#
#                                                                                                       level_1  \
# 0                                      In 2000, "I wrote about Osama bin Laden, ‘We’ve got to take him out.’"
# 1  Says in 2000, Fox News broke the story of George W. Bush’s drunk driving arrest. "Who broke it? Fox News."
# 2                                           A video shows a powerful jet of water flipping a child at a park.
# 3                        My numbers are better right now than Ronald Reagan's numbers were with Jimmy Carter.
# 4                          The U.S. Congress is considering passage of the "Americans with No Abilities" Act.
#
#                                                                                                   level_2  \
# 0       /virginia/statements/2015/dec/11/donald-trump/much-hype-trumps-claim-he-called-rubbing-out-bin-l/
# ...
